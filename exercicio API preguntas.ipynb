# %% [markdown]
# ### Una visita a Marte
# Un pequeño recorrido por Marte a través de las imágenes obtenidas por los robots Curiosity, Opportunity y Spirit
#
# ![Curiosity_rover.png](attachment:80353277-bf01-439c-96f3-e61cdb7078d0.png)
# ![Opportunity_rover.png](attachment:c415cbae-f412-49e5-af42-a324083a2dd9.png)
# ![Spirit_rover.png](attachment:839ba812-8c5a-4002-9679-d1401311f466.png)

# %%
# https://github.com/chrisccerami/mars-photo-api
# https://api.nasa.gov/  -----------> API Mars Rover Photos


# endpoint
# https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos   (el nombre del robot se puede cambiar)

# parámetros:

# sol = número ---> acceder por número de día marciano del robot en Marte desde su aterrizaje
# earth_date = aaa-m-d ---> acceder por fecha terrestre
# api_key = DEMO_KEY ---> demo con limitaciones, dan clave personal gratuita
# 25 imagenes máx. por respuesta, si hay más se puede usar el parámetro page para indicar la pagína de respuesta (1,2,...)
# camera = nombre_cámara (no los 3 robots tienen todas las cámaras, ver tabla en la web https://api.nasa.gov/   (desplegar API Mars Rover Photos))

# %%
# Importa a libraría para traballar con APIs

# %%
# Configura un endpoint con los parámetros que quieras
# consigue una api key y accede identificandote para evitar las limitaciones de acceder con clave demo (autenticación)

# %%
# fai unha primeira petición contra o endpoint
# Verifica o estado da resposta

# %%
# visualiza o contido da respoista en formato JSON

# %%
# cuenta cuantas fotos hizo cada robot en su primer día en Marte

# %%
# muestra la primera foto del día de la navcam del robot y fecha que quieras:

# %%
# Muestra la fecha de lanzamiento y de llegada de algún robot:

# %%
# muestra una foto aleotaria y todos sus datos, que cambie cada vez que se ejecute
